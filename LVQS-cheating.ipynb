# %%
import numpy as np
import matplotlib.pyplot as plt
from numba import jit
import scipy.stats as stats
import time
np.random.seed(0)
file='final_results_2'

# %%
@jit
def binary_(n, num_QS):
    """Converts a decimal number to binary with length num_QS"""
    bin_str=np.zeros(num_QS, dtype=np.int64)
    if n == 0:
        return bin_str
    i=0
    while n > 0:
        bin_str[i] = n % 2
        n //= 2
        i = i+1
    return np.flip(bin_str)

# %%
@jit
def decimal_(bin_str, num_QS):
    """Converts a binary number to decimal with length num_QS"""

    bin_str=np.flip(bin_str)
    n=0
    for ii in range(num_QS):
        n = n+(2**ii)*bin_str[ii]
    return np.int_(n)

# %%
@jit
def row_column(qsn,beta0,num_strains,center,beta_s,p,NN_max,alpha):
    "Reasigns an interaction coefficient related to species number qsn in the"
    "initial interaction matrix beta0 of size num_strainsxnum_strains. Coefficients are"
    "taken from a gaussian distribution of mean 0 and standard deviation beta_s."
    "p is the replacement probability."
    "beta_prime is the matrix with modified coefficients"
    
    beta_prime=np.copy(beta0)
    
    for j in range(num_strains+1):
        if np.random.rand() <= p:
            beta_prime[qsn,j] = np.random.normal(loc=center, scale=beta_s)
    for k in range(num_strains+1):
        if np.random.rand() <= p:
            beta_prime[k,qsn] = np.random.normal(loc=center, scale=beta_s)

    return beta_prime

# %%
@jit
def interact_matrices(num_strains,center,beta_s,num_QS,alpha,NN_max): 
    "Defines the interaction matrices for each QS activity state."
    "center is the mean of a guassian distribution for interaction coefficients and beta_s its standrd deviation."
    "num_QS is the number of QS species in the community. alpha is the growth rate constant and NN_max the carrying capacity."
    "Beta is an array that contains all the interaction matrices. qs_s contains the index of each QS species."
    
    qs_s=np.arange(num_QS+1).astype(np.int64) 
    qs_s=np.delete(qs_s,1)

    p=0.3        #Probability with each QS strain affecs or is affected by the other strains

    beta = np.zeros((2**num_QS,num_strains+1,num_strains+1))

    beta[0] = np.random.normal(center, beta_s, (num_strains+1, num_strains+1))     #Beta with random entrees

    beta[0][1,:] = np.copy(beta[0][0,:])
    beta[0][:,1] = np.copy(beta[0][:,0])  #cheaters interact equally with the other strains at low densities

    beta[0][1,0] = -alpha[0]/(NN_max)
    beta[0][0,1] = -alpha[1]/(NN_max) #The QS strain doesn't interact with its daugther mutants at low densities (only saturation effects)

    for ll in range(num_strains+1):
        beta[0][ll,ll]=-alpha[ll]/NN_max

    beta[0][0,0] = beta[0][0,0] 
    beta[0][1,1] = beta[0][1,1] 
    
    ind_QS=np.zeros(num_QS, dtype=np.int64)

    for ii in range(num_QS):
        #Define int matrices for single QS species activation
        binary=np.zeros(num_QS, dtype=np.int64)
        binary[ii]=1
        binary=np.flip(binary)
        ind=decimal_(binary,num_QS)
        ind_QS[ii]=ind
        beta0=np.copy(beta[0])
        nqs=qs_s[ii]
        beta[ind]=row_column(nqs,beta0,num_strains,center,beta_s,p,NN_max,alpha) #replace few terms of row and collumn
                                                                                 #nqs of the low density interaction matrix 

        beta[ind][1,:] = np.copy(beta[0][0,:])
        beta[ind][:,1] = np.copy(beta[0][:,0])

        beta[ind][1,0] = -alpha[0]/(NN_max)
        beta[ind][0,1] = -alpha[1]/(NN_max) #The QS strain doesn't interact with its daugther mutants at low densities (only saturation effects)

        for ll in range(num_strains+1):
            beta[ind][ll,ll]=-alpha[ll]/NN_max

        beta[ind][0,0] = beta[0][0,0]
        beta[ind][1,1] = beta[0][1,1] 

    for ii in range(2**num_QS-1):
        #Define matrices with more than one QS species active
        #Previous defined matrices copy themselfs, so they remain unchanged
        binary=np.flip(binary_(ii+1, num_QS))
        nqs=qs_s[binary==1]
        nind=ind_QS[binary==1]
        beta22=np.copy(beta[0])
        for jj in range(len(nind)):
            ind=nind[jj]
            ind_qs=nqs[jj]
            beta11=np.copy(beta[ind])   
            for k in range(num_strains+1):
                beta22[ind_qs,k]=beta11[ind_qs,k]
                beta22[k,ind_qs]=beta11[k,ind_qs]
        for k1 in nqs:
            for k2 in nqs:
                if np.random.rand() <= p:
                    beta22[k1,k2]=np.random.normal(loc=center, scale=beta_s)
        
        beta[ii+1]=beta22
        beta[ii+1][1,:] = np.copy(beta[0][0,:])
        beta[ii+1][:,1] = np.copy(beta[0][:,0])
        beta[ii+1][1,0] = -alpha[0]/(NN_max)
        beta[ii+1][0,1] = -alpha[1]/(NN_max) #The QS strain doesn't interact with its daugther mutants at low densities (only saturation effects)
        for ll in range(num_strains+1):
            beta[ii+1][ll,ll]=-alpha[ll]/NN_max
        beta[ii+1][0,0] = beta[0][0,0] 
        beta[ii+1][1,1] = beta[0][1,1]

    return beta, qs_s

# %%
@jit
def ff_i(t,i,alpha,beta1_,yy):
    "Lotka-Volterra equations"
    return yy[i]*(alpha[i]+(beta1_ @ yy)[i])

# %%
@jit
def reseed(N,N_max,reseed_num,num_strains,x):
    "Reseeding of cells."
    "N are the population densities, N_max the maximum total cell density, reseed_num the density after the transfer,"
    "and x the time control."
    
    total_density = np.sum(N)
    N_2=N.copy()
    y=False
    
    if total_density > N_max:

        fractions_r=np.empty(num_strains).astype(np.float64)

        for k in range(num_strains):
            fractions_r[k] = N_2[k] / total_density

        #Bins induced by the fractions of the species.
        cumulative_fractions=np.zeros(num_strains+1)

        cs=0
        for k in range(num_strains):
            cs=cs+fractions_r[k]
            cumulative_fractions[k+1]=cs
        
        #generate random numbers
        cell_partition=np.zeros(reseed_num).astype(np.float64)
        for k in range(reseed_num):
            cell_partition[k]=np.random.random_sample()
            
        #Finding the new_N. Histogram counts the number of cells in each bin.
        new_N, bins = np.histogram(cell_partition, bins=cumulative_fractions)
        y=True

        new_N=new_N.astype(np.float64)
        
        return new_N, True
    
    if x:
        
        fractions_r=np.empty(num_strains).astype(np.float64)

        for k in range(num_strains):
            fractions_r[k] = N_2[k] / total_density

        #Bins induced by the fractions of the species.
        cumulative_fractions=np.zeros(num_strains+1)

        cs=0
        for k in range(num_strains):
            cs=cs+fractions_r[k]
            cumulative_fractions[k+1]=cs
        
        #generate random numbers
        cell_partition=np.zeros(reseed_num).astype(np.float64)
        for k in range(reseed_num):
            cell_partition[k]=np.random.random_sample()
                    
        #Finding the new_N. Histogram counts the number of cells in each bin.
        new_N, bins = np.histogram(cell_partition, bins=cumulative_fractions)
        y=True

        new_N=new_N.astype(np.float64)
        
        return new_N, True
    
    return N, y

# %%
@jit
def RK4_GLVQS(N_initial,N_critical,N_max,num_strains,alpha,beta,reseed_number,target_reseeds,qs_list):
    "Runge-Kutta order 4 numerical solver modified to capture the QS activity state and cells tranfers."
    "frac contains the fraction of each population at each cells transfer."
    "survv contains the number of survivors at each cells transfer."
    
    reseed_count = 0
    hh=0.005                                             #time step
    tt=0.0                                                 #Initial time
    time_con=0.
    
    num_QS=len(qs_list)
    qs_act=np.zeros(num_QS)
    
    NN=N_initial.copy()
    ww2=np.zeros(num_strains+1)                              #Auxiliars to RK4 
    ww3=np.zeros(num_strains+1)
    ww4=np.zeros(num_strains+1)
    kk1=np.zeros(num_strains+1)
    kk2=np.zeros(num_strains+1)
    kk3=np.zeros(num_strains+1)
    kk4=np.zeros(num_strains+1)
    
    frac=np.zeros((target_reseeds+1,num_strains+1))
    for k in range(len(NN)):
        frac[0,k]=NN[k]/np.sum(NN)
    
    alpha_cost=np.copy(alpha)
                
    while reseed_count < target_reseeds:    
    #RK4 method
        
        x=False

        for i1 in range(num_QS):
            ind=qs_list[i1]
            if NN[ind]>N_critical[ind]:
                qs_act[i1]=1
            else:
                qs_act[i1]=0
                
        beta_ind=decimal_(np.flip(qs_act), num_QS)

        beta11=np.copy(beta[beta_ind])
        
        for j in range(num_strains+1):
            aa=ff_i(tt,j,alpha_cost,beta11,NN)
            kk1[j]=hh*aa
            bb=NN[j]
            ww2[j]=bb+(0.5*hh*aa)
        for j in range(num_strains+1):
            aa=ff_i(tt+(hh/2),j,alpha_cost,beta11,ww2)
            kk2[j]=hh*aa
            bb=NN[j]
            ww3[j]=bb+(0.5*hh*aa)
        for j in range(num_strains+1):
            aa=ff_i(tt+(hh/2),j,alpha_cost,beta11,ww3)
            kk3[j]=hh*aa
            bb=NN[j]
            ww4[j]=bb+(hh*aa)
        for j in range(num_strains+1):
            aa=ff_i(tt+hh,j,alpha_cost,beta11,ww4)
            kk4[j]=hh*aa
        for j in range(num_strains+1):
            NN[j]=NN[j]+(1./6.)*(kk1[j]+2.*kk2[j]+2.*kk3[j]+kk4[j])
            
        tt=tt+hh
        time_con=time_con+hh           #Time control
        for k in range(len(NN)):
            if NN[k]<0:
                NN[k]=0
            
        if time_con>12:                                                  
            x=True
            
        NN, reseeded = reseed(NN,N_max,reseed_number,num_strains+1,x)
            
        if reseeded:
            time_con=0
            reseed_count += 1

            for k in range(len(NN)):
                frac[reseed_count,k]=NN[k]/np.sum(NN)               
        
    return frac

# %%
@jit
def pop_dynamics(N_initial,N_critical,N_max,NN_max,num_strains,alpha,beta,reseed_number,hh,qs_list,cost):
    "Runge-Kutta order 4 numerical solver to visualize the population dynamics of each species."
    "frac contains the density of each species at each time step."
    
    reseed_count = 0
    tt=0.0                                                 #Initial time
    time_con=0.
    t_max=500000

    num_strains=num_strains+1
    
    num_QS=len(qs_list)
    
    NN=N_initial.copy()
    ww2=np.zeros(num_strains)                              #Auxiliars to RK4 
    ww3=np.zeros(num_strains)
    ww4=np.zeros(num_strains)
    kk1=np.zeros(num_strains)
    kk2=np.zeros(num_strains)
    kk3=np.zeros(num_strains)
    kk4=np.zeros(num_strains)
    frac=np.zeros((t_max,num_strains+1))
    frac[0,0]=0.0
    frac[0,1:]=NN.copy()

    alpha_c=1.95

    alpha_cost=np.copy(alpha)
    
    print('QS strains',qs_list)
    print(alpha_cost)

    reseeded=False
    
    for m in range(t_max-1):    
    #RK4 method

        qs_act=np.zeros(num_QS)
        
        x=False

        c_qs=0

        for i1 in range(num_QS):
            ind=qs_list[i1]
            if NN[ind]>N_critical[ind]:
                qs_act[i1]=1
                c_qs=c_qs+1
            else:
                qs_act[i1]=0

        beta_ind=decimal_(np.flip(qs_act), num_QS)

        beta11=np.copy(beta[beta_ind])
                
        if c_qs>0:
            print('QS act', m, qs_act, beta_ind)

        if reseeded:
            print('QS act res', m, qs_act, beta_ind)

        if m == 0:
            print(beta11)

        
        for j in range(num_strains):
            aa=ff_i(tt,j,alpha_cost,beta11,NN)
            kk1[j]=hh*aa
            bb=NN[j]
            ww2[j]=bb+(0.5*hh*aa)
        for j in range(num_strains):
            aa=ff_i(tt+(hh/2),j,alpha_cost,beta11,ww2)
            kk2[j]=hh*aa
            bb=NN[j]
            ww3[j]=bb+(0.5*hh*aa)
        for j in range(num_strains):
            aa=ff_i(tt+(hh/2),j,alpha_cost,beta11,ww3)
            kk3[j]=hh*aa
            bb=NN[j]
            ww4[j]=bb+(hh*aa)
        for j in range(num_strains):
            aa=ff_i(tt+hh,j,alpha_cost,beta11,ww4)
            kk4[j]=hh*aa
        for j in range(num_strains):
            NN[j]=NN[j]+(1./6.)*(kk1[j]+2.*kk2[j]+2.*kk3[j]+kk4[j])
            
        tt=tt+hh
        time_con=time_con+hh           #Time control
        for k in range(len(NN)):
            if NN[k]<0:
                NN[k]=0
            
        if time_con>8:                                                  
            x=True
            
        NN, reseeded = reseed(NN,N_max,reseed_number,num_strains,x)
            
        if reseeded:
            time_con=0
            reseed_count += 1

        frac[m+1,0]=tt
        for k in range(len(NN)):
            frac[m+1,k+1]=NN[k]
               
    return frac

# %%
@jit
def run_simulation(N_critical,N_critical_2,N_max,num_strains,alpha,center,beta_sig,num_QS,NN_max,reseed_num,target_reseeds,trlnumber,alpha_c,cost):
    "Runs the dynamical evolution for an ensamble of trlnumber random communities."
    "N_critical is the QS activation threshold of each QS spcies. N_max the maximum total density."
    "num_strains the number of species, alpha the growth rate constant, center is the mean of the gaussian distribution,"
    "beta_sig its standard deviation, num_QS the number of QS species,"
    "NN_max the carrying capacity, reseed_num the density after each cells transfer,"
    "target_reseeds the number of cells transfers, trlnumber the number of members of the ensamble,"
    "alpha_c is the reduced growth rate constant when the cost is active, cost tells if a cost to QS is considered or not."
    "fractions contains the population fractions at each cells transfer."
    "surv_num contains the number of survivors at each cells transfer."
    "qs_strains contains the indexes of each QS speciews of each random community."
    "The legend _NQS means that QS is not active."
    
    trials=range(trlnumber)
    fractions=np.zeros((trlnumber,target_reseeds+1,num_strains+1))
    fractions_NQS=np.zeros((trlnumber,target_reseeds+1,num_strains+1))
    qs_strains=np.zeros((trlnumber,num_strains+1))
    
    N_initial = np.full(num_strains+1, 1e5, dtype=np.float64)
    N_initial[0] = (90/100)*1e5
    N_initial[1] = (10/100)*1e5
    np.random.seed(0)

    if cost:
        alpha[0] = alpha_c

    for ii in trials:

        if ii%250==0:
            print(ii)

        beta, qs_list=interact_matrices(num_strains,center,beta_sig,num_QS,alpha,NN_max)
        frac = RK4_GLVQS(N_initial,N_critical,N_max,num_strains,alpha,beta,reseed_num,target_reseeds,qs_list,alpha_c,cost)
        frac_NQS = RK4_GLVQS(N_initial,N_critical_2,N_max,num_strains,alpha,beta,reseed_num,target_reseeds,qs_list,alpha_c,cost)
        
        fractions[ii,:,:]=frac
        fractions_NQS[ii,:,:]=frac_NQS
        
        for k in qs_list:
            qs_strains[ii][k]=1


    return fractions, fractions_NQS, qs_strains

# %%
#Parameters
trlnumber=5000
beta_sig = 10**(-9)
center=0
N_max = 1e10     #max community density
NN_max = 1e9   #carrying capacity
reseed_num = int(1e5)
target_reseeds = 200
res_point = 200
cost = True

# %%
x_var=np.array([1,5,10,15,20])
num_file=0
variable='cheating_90-10_20perc_25c_size_2_'

for ll in x_var:
    
    print(ll)

    num_strains=ll
    QS_perc = 20
    num_QS = int((num_strains*QS_perc)/100)

    if ll == 1:
        num_QS=1
    
    alpha_c=1.95

    N_critical = np.full(num_strains+1, 1e8, dtype=np.float64)
    N_critical_2 = np.full(num_strains+1, 1e18, dtype=np.float64)
    alpha = np.full(num_strains+1, 2, dtype=np.float64)
    
    file2=variable+str(ll)
    
    fractions, fractions_NQS, qs_s=run_simulation(N_critical,N_critical_2,N_max,num_strains,alpha,center,beta_sig,
                                   num_QS,NN_max,reseed_num,target_reseeds,trlnumber,alpha_c,cost)
    
    np.save(file+'/fractions_'+file2+'.npy', fractions)
    np.save(file+'/fractions_NQS_'+file2+'.npy', fractions_NQS)
    np.save(file+'/qs_'+file2+'.npy', qs_s)

    num_file=num_file+1
# Out:
# 1
# 0
# 250
# 500
# 750
# 1000
# 1250
# 1500
# 1750
# 2000
# 2250
# 2500
# 2750
# 3000
# 3250
# 3500
# 3750
# 4000
# 4250
# 4500
# 4750
# 5
# 0
# 250
# 500
# 750
# 1000
# 1250
# 1500
# 1750
# 2000
# 2250
# 2500
# 2750
# 3000
# 3250
# 3500
# 3750
# 4000
# 4250
# 4500
# 4750
# 10
# 0
# 250
# 500
# 750
# 1000
# 1250
# 1500
# 1750
# 2000
# 2250
# 2500
# 2750
# 3000
# 3250
# 3500
# 3750
# 4000
# 4250
# 4500
# 4750
# 15
# 0
# 250
# 500
# 750
# 1000
# 1250
# 1500
# 1750
# 2000
# 2250
# 2500
# 2750
# 3000
# 3250
# 3500
# 3750
# 4000
# 4250
# 4500
# 4750
# 20
# 0
# 250
# 500
# 750
# 1000
# 1250
# 1500
# 1750
# 2000
# 2250
# 2500
# 2750
# 3000
# 3250
# 3500
# 3750
# 4000
# 4250
# 4500
# 4750

# %% [markdown]
# # Populations dynamics example

# %%
num_strains=5
num_QS=1
alpha = np.full(num_strains+1, 2, dtype=np.float64)
alpha[0] = 1.95
N_initial = np.full(num_strains+1, 1e5, dtype=np.float64)
N_critical = np.full(num_strains+1, 1e8, dtype=np.float64)
N_initial[0] = (90/100)*1e5
N_initial[1] = (10/100)*1e5
cost=True
beta, qs_list=interact_matrices(num_strains,center,beta_sig,num_QS,alpha,NN_max)
frac=pop_dynamics(N_initial,N_critical,N_max,NN_max,num_strains,alpha,beta,reseed_num,0.1,qs_list,cost)
# Out:
# QS strains [0]
# [1.95 2.   2.   2.   2.   2.  ]
# [[-1.95000000e-09 -2.00000000e-09  8.86444744e-10  1.32979762e-10
#   -1.79071051e-09 -1.14090990e-09]
#  [-1.95000000e-09 -2.00000000e-09  8.86444744e-10  1.32979762e-10
#   -1.79071051e-09 -1.14090990e-09]
#  [ 2.75751967e-10  2.75751967e-10 -2.00000000e-09 -1.38834463e-09
#    9.37549957e-11  8.01226603e-10]
#  [ 7.78518525e-10  7.78518525e-10 -7.51922249e-10 -2.00000000e-09
#    1.62999185e-10 -5.68353757e-10]
#  [ 6.94773464e-10  6.94773464e-10 -1.47763828e-09 -4.54527985e-10
#   -2.00000000e-09 -9.53464466e-10]
#  [-1.40926755e-10 -1.40926755e-10 -4.42487164e-11  3.30829562e-10
#   -5.68367668e-10 -2.00000000e-09]]
# QS act 38 [1.] 1
# QS act 39 [1.] 1
# QS act 40 [1.] 1
# QS act 41 [1.] 1
# QS act 42 [1.] 1
# QS act 43 [1.] 1
# QS act 44 [1.] 1
# QS act 45 [1.] 1
# QS act 46 [1.] 1
# QS act 47 [1.] 1
# QS act 48 [1.] 1
# QS act 49 [1.] 1
# QS act 50 [1.] 1
# QS act 51 [1.] 1
# QS act 52 [1.] 1
# QS act 53 [1.] 1
# QS act 54 [1.] 1
# QS act 55 [1.] 1
# QS act 56 [1.] 1
# QS act 57 [1.] 1
# QS act 58 [1.] 1
# QS act 59 [1.] 1
# QS act 60 [1.] 1
# QS act 61 [1.] 1
# QS act 62 [1.] 1
# QS act 63 [1.] 1
# QS act 64 [1.] 1
# QS act 65 [1.] 1
# QS act 66 [1.] 1
# QS act 67 [1.] 1
# QS act 68 [1.] 1
# QS act 69 [1.] 1
# QS act 70 [1.] 1
# QS act 71 [1.] 1
# QS act 72 [1.] 1
# QS act 73 [1.] 1
# QS act 74 [1.] 1
# QS act 75 [1.] 1
# QS act 76 [1.] 1
# QS act 77 [1.] 1
# QS act 78 [1.] 1
# QS act 79 [1.] 1
# QS act 80 [1.] 1
# QS act res 81 [0.] 0
# QS act 134 [1.] 1
# QS act 135 [1.] 1
# QS act 136 [1.] 1
# QS act 137 [1.] 1
# QS act 138 [1.] 1
# QS act 139 [1.] 1
# QS act 140 [1.] 1
# QS act 141 [1.] 1
# QS act 142 [1.] 1
# QS act 143 [1.] 1
# QS act 144 [1.] 1
# QS act 145 [1.] 1
# QS act 146 [1.] 1
# QS act 149 [1.] 1
# QS act res 162 [0.] 0
# QS act res 243 [0.] 0
# QS act res 324 [0.] 0
# QS act res 405 [0.] 0
# QS act res 486 [0.] 0
# QS act res 567 [0.] 0
# QS act res 648 [0.] 0
# QS act res 729 [0.] 0
# QS act res 810 [0.] 0
# QS act res 891 [0.] 0
# QS act res 972 [0.] 0
# QS act res 1053 [0.] 0
# QS act res 1134 [0.] 0
# QS act res 1215 [0.] 0
# QS act res 1296 [0.] 0
# QS act res 1377 [0.] 0
# QS act res 1458 [0.] 0
# QS act res 1539 [0.] 0
# QS act res 1620 [0.] 0
# QS act res 1701 [0.] 0
# QS act res 1782 [0.] 0
# QS act res 1863 [0.] 0
# QS act res 1944 [0.] 0
# QS act res 2025 [0.] 0
# QS act res 2106 [0.] 0
# QS act res 10044 [0.] 0
# QS act res 10125 [0.] 0
# QS act res 10206 [0.] 0
# QS act res 10287 [0.] 0
# QS act res 10368 [0.] 0
# QS act res 10449 [0.] 0
# QS act res 10530 [0.] 0
# QS act res 10611 [0.] 0
# QS act res 10692 [0.] 0
# QS act res 10773 [0.] 0
# QS act res 10854 [0.] 0
# QS act res 10935 [0.] 0
# QS act res 11016 [0.] 0
# QS act res 11097 [0.] 0
# QS act res 11178 [0.] 0
# QS act res 11259 [0.] 0
# QS act res 11340 [0.] 0
# QS act res 11421 [0.] 0
# QS act res 11502 [0.] 0
# QS act res 11583 [0.] 0
# QS act res 11664 [0.] 0
# QS act res 11745 [0.] 0
# QS act res 11826 [0.] 0
# QS act res 11907 [0.] 0
# QS act res 11988 [0.] 0
# QS act res 12069 [0.] 0
# QS act res 12150 [0.] 0
# QS act res 12231 [0.] 0
# QS act res 12312 [0.] 0
# QS act res 12393 [0.] 0
# QS act res 12474 [0.] 0
# QS act res 12555 [0.] 0
# QS act res 12636 [0.] 0
# QS act res 12717 [0.] 0
# QS act res 12798 [0.] 0
# QS act res 12879 [0.] 0
# QS act res 12960 [0.] 0
# QS act res 13041 [0.] 0
# QS act res 13122 [0.] 0
# QS act res 13203 [0.] 0
# QS act res 13284 [0.] 0
# QS act res 13365 [0.] 0
# QS act res 13446 [0.] 0
# QS act res 13527 [0.] 0
# QS act res 13608 [0.] 0
# QS act res 13689 [0.] 0
# QS act res 13770 [0.] 0
# QS act res 13851 [0.] 0
# QS act res 13932 [0.] 0
# QS act res 14013 [0.] 0
# QS act res 14094 [0.] 0
# QS act res 14175 [0.] 0
# QS act res 14256 [0.] 0
# QS act res 14337 [0.] 0
# QS act res 14418 [0.] 0
# QS act res 14499 [0.] 0
# QS act res 14580 [0.] 0
# QS act res 14661 [0.] 0
# QS act res 14742 [0.] 0
# QS act res 14823 [0.] 0
# QS act res 14904 [0.] 0
# QS act res 14985 [0.] 0
# QS act res 15066 [0.] 0
# QS act res 15147 [0.] 0
# QS act res 15228 [0.] 0
# QS act res 15309 [0.] 0
# QS act res 15390 [0.] 0
# QS act res 15471 [0.] 0
# QS act res 15552 [0.] 0
# QS act res 15633 [0.] 0
# QS act res 15714 [0.] 0
# QS act res 15795 [0.] 0
# QS act res 15876 [0.] 0
# QS act res 15957 [0.] 0
# QS act res 16038 [0.] 0
# QS act res 16119 [0.] 0
# QS act res 16200 [0.] 0
# QS act res 16281 [0.] 0
# QS act res 16362 [0.] 0
# QS act res 16443 [0.] 0
# QS act res 16524 [0.] 0
# QS act res 16605 [0.] 0
# QS act res 16686 [0.] 0
# QS act res 16767 [0.] 0
# QS act res 16848 [0.] 0
# QS act res 16929 [0.] 0
# QS act res 17010 [0.] 0
# QS act res 17091 [0.] 0
# QS act res 17172 [0.] 0
# QS act res 17253 [0.] 0
# QS act res 17334 [0.] 0
# QS act res 17415 [0.] 0
# QS act res 17496 [0.] 0
# QS act res 17577 [0.] 0
# QS act res 17658 [0.] 0
# QS act res 17739 [0.] 0
# QS act res 17820 [0.] 0
# QS act res 17901 [0.] 0
# QS act res 41553 [0.] 0
# QS act res 41634 [0.] 0
# QS act res 41715 [0.] 0
# QS act res 41796 [0.] 0
# QS act res 41877 [0.] 0
# QS act res 41958 [0.] 0
# QS act res 42039 [0.] 0
# QS act res 42120 [0.] 0
# QS act res 42201 [0.] 0
# QS act res 42282 [0.] 0
# QS act res 42363 [0.] 0
# QS act res 42444 [0.] 0
# QS act res 42525 [0.] 0
# QS act res 42606 [0.] 0
# QS act res 42687 [0.] 0
# QS act res 42768 [0.] 0
# QS act res 42849 [0.] 0
# QS act res 42930 [0.] 0
# QS act res 43011 [0.] 0
# QS act res 43092 [0.] 0
# QS act res 43173 [0.] 0
# QS act res 43254 [0.] 0
# QS act res 43335 [0.] 0
# QS act res 43416 [0.] 0
# QS act res 43497 [0.] 0
# QS act res 43578 [0.] 0
# QS act res 43659 [0.] 0
# QS act res 43740 [0.] 0
# QS act res 43821 [0.] 0
# QS act res 43902 [0.] 0
# QS act res 43983 [0.] 0
# QS act res 44064 [0.] 0
# QS act res 44145 [0.] 0
# QS act res 44226 [0.] 0
# QS act res 44307 [0.] 0
# QS act res 44388 [0.] 0
# QS act res 44469 [0.] 0
# QS act res 44550 [0.] 0
# QS act res 44631 [0.] 0
# QS act res 44712 [0.] 0
# QS act res 44793 [0.] 0
# QS act res 44874 [0.] 0
# QS act res 44955 [0.] 0
# QS act res 45036 [0.] 0
# QS act res 45117 [0.] 0
# QS act res 45198 [0.] 0
# QS act res 45279 [0.] 0
# QS act res 45360 [0.] 0
# QS act res 45441 [0.] 0
# QS act res 45522 [0.] 0
# QS act res 45603 [0.] 0
# QS act res 45684 [0.] 0
# QS act res 45765 [0.] 0
# QS act res 45846 [0.] 0
# QS act res 45927 [0.] 0
# QS act res 46008 [0.] 0
# QS act res 46089 [0.] 0
# QS act res 46170 [0.] 0
# QS act res 46251 [0.] 0
# QS act res 46332 [0.] 0
# QS act res 46413 [0.] 0
# QS act res 46494 [0.] 0
# QS act res 46575 [0.] 0
# QS act res 46656 [0.] 0
# QS act res 46737 [0.] 0
# QS act res 46818 [0.] 0
# QS act res 46899 [0.] 0
# QS act res 46980 [0.] 0
# QS act res 47061 [0.] 0
# QS act res 47142 [0.] 0
# QS act res 47223 [0.] 0
# QS act res 47304 [0.] 0
# QS act res 47385 [0.] 0
# QS act res 47466 [0.] 0
# QS act res 47547 [0.] 0
# QS act res 47628 [0.] 0
# QS act res 47709 [0.] 0
# QS act res 47790 [0.] 0
# QS act res 47871 [0.] 0
# QS act res 47952 [0.] 0
# QS act res 48033 [0.] 0
# QS act res 48114 [0.] 0
# QS act res 48195 [0.] 0
# QS act res 48276 [0.] 0
# QS act res 48357 [0.] 0
# QS act res 48438 [0.] 0
# QS act res 48519 [0.] 0
# QS act res 48600 [0.] 0
# QS act res 48681 [0.] 0
# QS act res 48762 [0.] 0
# QS act res 48843 [0.] 0
# QS act res 48924 [0.] 0
# QS act res 49005 [0.] 0
# QS act res 49086 [0.] 0
# QS act res 49167 [0.] 0
# QS act res 49248 [0.] 0
# QS act res 49329 [0.] 0
# QS act res 49410 [0.] 0
# QS act res 88857 [0.] 0
# QS act res 88938 [0.] 0
# QS act res 89019 [0.] 0
# QS act res 89100 [0.] 0
# QS act res 89181 [0.] 0
# QS act res 89262 [0.] 0
# QS act res 89343 [0.] 0
# QS act res 89424 [0.] 0
# QS act res 89505 [0.] 0
# QS act res 89586 [0.] 0
# QS act res 89667 [0.] 0
# QS act res 89748 [0.] 0
# QS act res 89829 [0.] 0
# QS act res 89910 [0.] 0
# QS act res 89991 [0.] 0
# QS act res 90072 [0.] 0
# QS act res 90153 [0.] 0
# QS act res 90234 [0.] 0
# QS act res 90315 [0.] 0
# QS act res 90396 [0.] 0
# QS act res 90477 [0.] 0
# QS act res 90558 [0.] 0
# QS act res 90639 [0.] 0
# QS act res 90720 [0.] 0
# QS act res 90801 [0.] 0
# QS act res 90882 [0.] 0
# QS act res 90963 [0.] 0
# QS act res 91044 [0.] 0
# QS act res 91125 [0.] 0
# QS act res 91206 [0.] 0
# QS act res 91287 [0.] 0
# QS act res 91368 [0.] 0
# QS act res 91449 [0.] 0
# QS act res 91530 [0.] 0
# QS act res 91611 [0.] 0
# QS act res 91692 [0.] 0
# QS act res 91773 [0.] 0
# QS act res 91854 [0.] 0
# QS act res 91935 [0.] 0
# QS act res 92016 [0.] 0
# QS act res 92097 [0.] 0
# QS act res 92178 [0.] 0
# QS act res 92259 [0.] 0
# QS act res 92340 [0.] 0
# QS act res 92421 [0.] 0
# QS act res 92502 [0.] 0
# QS act res 92583 [0.] 0
# QS act res 92664 [0.] 0
# QS act res 92745 [0.] 0
# QS act res 92826 [0.] 0
# QS act res 92907 [0.] 0
# QS act res 92988 [0.] 0
# QS act res 93069 [0.] 0
# QS act res 93150 [0.] 0
# QS act res 93231 [0.] 0
# QS act res 93312 [0.] 0
# QS act res 93393 [0.] 0
# QS act res 93474 [0.] 0
# QS act res 93555 [0.] 0
# QS act res 93636 [0.] 0
# QS act res 93717 [0.] 0
# QS act res 93798 [0.] 0
# QS act res 93879 [0.] 0
# QS act res 93960 [0.] 0
# QS act res 94041 [0.] 0
# QS act res 94122 [0.] 0
# QS act res 94203 [0.] 0
# QS act res 94284 [0.] 0
# QS act res 94365 [0.] 0
# QS act res 94446 [0.] 0
# QS act res 94527 [0.] 0
# QS act res 94608 [0.] 0
# QS act res 94689 [0.] 0
# QS act res 94770 [0.] 0
# QS act res 94851 [0.] 0
# QS act res 94932 [0.] 0
# QS act res 95013 [0.] 0
# QS act res 95094 [0.] 0
# QS act res 95175 [0.] 0
# QS act res 95256 [0.] 0
# QS act res 95337 [0.] 0
# QS act res 95418 [0.] 0
# QS act res 95499 [0.] 0
# QS act res 95580 [0.] 0
# QS act res 95661 [0.] 0
# QS act res 95742 [0.] 0
# QS act res 95823 [0.] 0
# QS act res 95904 [0.] 0
# QS act res 95985 [0.] 0
# QS act res 96066 [0.] 0
# QS act res 96147 [0.] 0
# QS act res 96228 [0.] 0
# QS act res 96309 [0.] 0
# QS act res 96390 [0.] 0
# QS act res 96471 [0.] 0
# QS act res 96552 [0.] 0
# QS act res 96633 [0.] 0
# QS act res 104571 [0.] 0
# QS act res 104652 [0.] 0
# QS act res 104733 [0.] 0
# QS act res 104814 [0.] 0
# QS act res 104895 [0.] 0
# QS act res 104976 [0.] 0
# QS act res 105057 [0.] 0
# QS act res 105138 [0.] 0
# QS act res 105219 [0.] 0
# QS act res 105300 [0.] 0
# QS act res 105381 [0.] 0
# QS act res 105462 [0.] 0
# QS act res 105543 [0.] 0
# QS act res 105624 [0.] 0
# QS act res 105705 [0.] 0
# QS act res 105786 [0.] 0
# QS act res 105867 [0.] 0
# QS act res 105948 [0.] 0
# QS act res 106029 [0.] 0
# QS act res 106110 [0.] 0
# QS act res 106191 [0.] 0
# QS act res 106272 [0.] 0
# QS act res 106353 [0.] 0
# QS act res 106434 [0.] 0
# QS act res 106515 [0.] 0
# QS act res 106596 [0.] 0
# QS act res 106677 [0.] 0
# QS act res 106758 [0.] 0
# QS act res 106839 [0.] 0
# QS act res 106920 [0.] 0
# QS act res 107001 [0.] 0
# QS act res 107082 [0.] 0
# QS act res 107163 [0.] 0
# QS act res 107244 [0.] 0
# QS act res 107325 [0.] 0
# QS act res 107406 [0.] 0
# QS act res 107487 [0.] 0
# QS act res 107568 [0.] 0
# QS act res 107649 [0.] 0
# QS act res 107730 [0.] 0
# QS act res 107811 [0.] 0
# QS act res 107892 [0.] 0
# QS act res 107973 [0.] 0
# QS act res 108054 [0.] 0
# QS act res 108135 [0.] 0
# QS act res 108216 [0.] 0
# QS act res 108297 [0.] 0
# QS act res 108378 [0.] 0
# QS act res 108459 [0.] 0
# QS act res 108540 [0.] 0
# QS act res 108621 [0.] 0
# QS act res 108702 [0.] 0
# QS act res 108783 [0.] 0
# QS act res 108864 [0.] 0
# QS act res 108945 [0.] 0
# QS act res 109026 [0.] 0
# QS act res 109107 [0.] 0
# QS act res 109188 [0.] 0
# QS act res 109269 [0.] 0
# QS act res 109350 [0.] 0
# QS act res 109431 [0.] 0
# QS act res 109512 [0.] 0
# QS act res 109593 [0.] 0
# QS act res 109674 [0.] 0
# QS act res 109755 [0.] 0
# QS act res 109836 [0.] 0
# QS act res 109917 [0.] 0
# QS act res 109998 [0.] 0
# QS act res 110079 [0.] 0
# QS act res 110160 [0.] 0
# QS act res 110241 [0.] 0
# QS act res 110322 [0.] 0
# QS act res 110403 [0.] 0
# QS act res 110484 [0.] 0
# QS act res 110565 [0.] 0
# QS act res 110646 [0.] 0
# QS act res 110727 [0.] 0
# QS act res 110808 [0.] 0
# QS act res 110889 [0.] 0
# QS act res 110970 [0.] 0
# QS act res 111051 [0.] 0
# QS act res 111132 [0.] 0
# QS act res 111213 [0.] 0
# QS act res 111294 [0.] 0
# QS act res 111375 [0.] 0
# QS act res 111456 [0.] 0
# QS act res 111537 [0.] 0
# QS act res 111618 [0.] 0
# QS act res 111699 [0.] 0
# QS act res 111780 [0.] 0
# QS act res 111861 [0.] 0
# QS act res 111942 [0.] 0
# QS act res 112023 [0.] 0
# QS act res 112104 [0.] 0
# QS act res 112185 [0.] 0
# QS act res 112266 [0.] 0
# QS act res 112347 [0.] 0
# QS act res 112428 [0.] 0
# QS act res 112509 [0.] 0
# QS act res 112590 [0.] 0
# QS act res 112671 [0.] 0
# QS act res 112752 [0.] 0
# QS act res 112833 [0.] 0
# QS act res 112914 [0.] 0
# QS act res 112995 [0.] 0
# QS act res 113076 [0.] 0
# QS act res 113157 [0.] 0
# QS act res 113238 [0.] 0
# QS act res 113319 [0.] 0
# QS act res 113400 [0.] 0
# QS act res 113481 [0.] 0
# QS act res 113562 [0.] 0
# QS act res 113643 [0.] 0
# QS act res 113724 [0.] 0
# QS act res 113805 [0.] 0
# QS act res 113886 [0.] 0
# QS act res 113967 [0.] 0
# QS act res 114048 [0.] 0
# QS act res 114129 [0.] 0
# QS act res 114210 [0.] 0
# QS act res 114291 [0.] 0
# QS act res 114372 [0.] 0
# QS act res 114453 [0.] 0
# QS act res 114534 [0.] 0
# QS act res 114615 [0.] 0
# QS act res 114696 [0.] 0
# QS act res 114777 [0.] 0
# QS act res 114858 [0.] 0
# QS act res 114939 [0.] 0
# QS act res 115020 [0.] 0
# QS act res 115101 [0.] 0
# QS act res 115182 [0.] 0
# QS act res 115263 [0.] 0
# QS act res 115344 [0.] 0
# QS act res 115425 [0.] 0
# QS act res 115506 [0.] 0
# QS act res 115587 [0.] 0
# QS act res 115668 [0.] 0
# QS act res 115749 [0.] 0
# QS act res 115830 [0.] 0
# QS act res 115911 [0.] 0
# QS act res 115992 [0.] 0
# QS act res 116073 [0.] 0
# QS act res 116154 [0.] 0
# QS act res 116235 [0.] 0
# QS act res 116316 [0.] 0
# QS act res 116397 [0.] 0
# QS act res 116478 [0.] 0
# QS act res 116559 [0.] 0
# QS act res 116640 [0.] 0
# QS act res 116721 [0.] 0
# QS act res 116802 [0.] 0
# QS act res 116883 [0.] 0
# QS act res 116964 [0.] 0
# QS act res 117045 [0.] 0
# QS act res 117126 [0.] 0
# QS act res 117207 [0.] 0
# QS act res 117288 [0.] 0
# QS act res 117369 [0.] 0
# QS act res 117450 [0.] 0
# QS act res 117531 [0.] 0
# QS act res 117612 [0.] 0
# QS act res 117693 [0.] 0
# QS act res 117774 [0.] 0
# QS act res 117855 [0.] 0
# QS act res 117936 [0.] 0
# QS act res 118017 [0.] 0
# QS act res 118098 [0.] 0
# QS act res 118179 [0.] 0
# QS act res 118260 [0.] 0
# QS act res 118341 [0.] 0
# QS act res 118422 [0.] 0
# QS act res 118503 [0.] 0
# QS act res 118584 [0.] 0
# QS act res 118665 [0.] 0
# QS act res 118746 [0.] 0
# QS act res 118827 [0.] 0
# QS act res 118908 [0.] 0
# QS act res 118989 [0.] 0
# QS act res 119070 [0.] 0
# QS act res 119151 [0.] 0
# QS act res 119232 [0.] 0
# QS act res 119313 [0.] 0
# QS act res 119394 [0.] 0
# QS act res 119475 [0.] 0
# QS act res 119556 [0.] 0
# QS act res 119637 [0.] 0
# QS act res 119718 [0.] 0
# QS act res 119799 [0.] 0
# QS act res 119880 [0.] 0
# QS act res 119961 [0.] 0
# QS act res 120042 [0.] 0
# QS act res 120123 [0.] 0
# QS act res 120204 [0.] 0
# QS act res 143937 [0.] 0
# QS act res 144018 [0.] 0
# QS act res 144099 [0.] 0
# QS act res 144180 [0.] 0
# QS act res 144261 [0.] 0
# QS act res 144342 [0.] 0
# QS act res 144423 [0.] 0
# QS act res 144504 [0.] 0
# QS act res 144585 [0.] 0
# QS act res 144666 [0.] 0
# QS act res 144747 [0.] 0
# QS act res 144828 [0.] 0
# QS act res 144909 [0.] 0
# QS act res 144990 [0.] 0
# QS act res 145071 [0.] 0
# QS act res 145152 [0.] 0
# QS act res 145233 [0.] 0
# QS act res 145314 [0.] 0
# QS act res 145395 [0.] 0
# QS act res 145476 [0.] 0
# QS act res 145557 [0.] 0
# QS act res 145638 [0.] 0
# QS act res 145719 [0.] 0
# QS act res 145800 [0.] 0
# QS act res 145881 [0.] 0
# QS act res 145962 [0.] 0
# QS act res 146043 [0.] 0
# QS act res 146124 [0.] 0
# QS act res 146205 [0.] 0
# QS act res 146286 [0.] 0
# QS act res 146367 [0.] 0
# QS act res 146448 [0.] 0
# QS act res 146529 [0.] 0
# QS act res 146610 [0.] 0
# QS act res 146691 [0.] 0
# QS act res 146772 [0.] 0
# QS act res 146853 [0.] 0
# QS act res 146934 [0.] 0
# QS act res 147015 [0.] 0
# QS act res 147096 [0.] 0
# QS act res 147177 [0.] 0
# QS act res 147258 [0.] 0
# QS act res 147339 [0.] 0
# QS act res 147420 [0.] 0
# QS act res 147501 [0.] 0
# QS act res 147582 [0.] 0
# QS act res 147663 [0.] 0
# QS act res 147744 [0.] 0
# QS act res 147825 [0.] 0
# QS act res 147906 [0.] 0
# QS act res 147987 [0.] 0
# QS act res 148068 [0.] 0
# QS act res 148149 [0.] 0
# QS act res 148230 [0.] 0
# QS act res 148311 [0.] 0
# QS act res 148392 [0.] 0
# QS act res 148473 [0.] 0
# QS act res 148554 [0.] 0
# QS act res 148635 [0.] 0
# QS act res 148716 [0.] 0
# QS act res 148797 [0.] 0
# QS act res 148878 [0.] 0
# QS act res 148959 [0.] 0
# QS act res 149040 [0.] 0
# QS act res 149121 [0.] 0
# QS act res 149202 [0.] 0
# QS act res 149283 [0.] 0
# QS act res 149364 [0.] 0
# QS act res 149445 [0.] 0
# QS act res 149526 [0.] 0
# QS act res 149607 [0.] 0
# QS act res 149688 [0.] 0
# QS act res 149769 [0.] 0
# QS act res 149850 [0.] 0
# QS act res 149931 [0.] 0
# QS act res 150012 [0.] 0
# QS act res 150093 [0.] 0
# QS act res 150174 [0.] 0
# QS act res 150255 [0.] 0
# QS act res 150336 [0.] 0
# QS act res 150417 [0.] 0
# QS act res 150498 [0.] 0
# QS act res 150579 [0.] 0
# QS act res 150660 [0.] 0
# QS act res 150741 [0.] 0
# QS act res 150822 [0.] 0
# QS act res 150903 [0.] 0
# QS act res 150984 [0.] 0
# QS act res 151065 [0.] 0
# QS act res 151146 [0.] 0
# QS act res 151227 [0.] 0
# QS act res 151308 [0.] 0
# QS act res 151389 [0.] 0
# QS act res 151470 [0.] 0
# QS act res 151551 [0.] 0
# QS act res 151632 [0.] 0
# QS act res 151713 [0.] 0
# QS act res 151794 [0.] 0
# QS act res 151875 [0.] 0
# QS act res 151956 [0.] 0
# QS act res 152037 [0.] 0
# QS act res 152118 [0.] 0
# QS act res 152199 [0.] 0
# QS act res 152280 [0.] 0
# QS act res 152361 [0.] 0
# QS act res 152442 [0.] 0
# QS act res 152523 [0.] 0
# QS act res 152604 [0.] 0
# QS act res 152685 [0.] 0
# QS act res 152766 [0.] 0
# QS act res 152847 [0.] 0
# QS act res 152928 [0.] 0
# QS act res 153009 [0.] 0
# QS act res 153090 [0.] 0
# QS act res 153171 [0.] 0
# QS act res 153252 [0.] 0
# QS act res 153333 [0.] 0
# QS act res 153414 [0.] 0
# QS act res 153495 [0.] 0
# QS act res 153576 [0.] 0
# QS act res 153657 [0.] 0
# QS act res 153738 [0.] 0
# QS act res 153819 [0.] 0
# QS act res 153900 [0.] 0
# QS act res 153981 [0.] 0
# QS act res 154062 [0.] 0
# QS act res 154143 [0.] 0
# QS act res 154224 [0.] 0
# QS act res 154305 [0.] 0
# QS act res 154386 [0.] 0
# QS act res 154467 [0.] 0
# QS act res 154548 [0.] 0
# QS act res 154629 [0.] 0
# ...
# QS act res 448173 [0.] 0
# QS act res 448254 [0.] 0
# QS act res 448335 [0.] 0
# QS act res 448416 [0.] 0
# QS act res 448497 [0.] 0
# QS act res 448578 [0.] 0
# QS act res 448659 [0.] 0
# QS act res 448740 [0.] 0
# QS act res 448821 [0.] 0
# QS act res 448902 [0.] 0
# QS act res 448983 [0.] 0
# QS act res 449064 [0.] 0
# QS act res 449145 [0.] 0
# QS act res 449226 [0.] 0
# QS act res 449307 [0.] 0
# QS act res 449388 [0.] 0
# QS act res 449469 [0.] 0
# QS act res 449550 [0.] 0
# QS act res 449631 [0.] 0
# QS act res 449712 [0.] 0
# QS act res 449793 [0.] 0
# QS act res 449874 [0.] 0
# QS act res 449955 [0.] 0
# QS act res 450036 [0.] 0
# QS act res 450117 [0.] 0
# QS act res 450198 [0.] 0
# QS act res 450279 [0.] 0
# QS act res 450360 [0.] 0
# QS act res 450441 [0.] 0
# QS act res 450522 [0.] 0
# QS act res 450603 [0.] 0
# QS act res 450684 [0.] 0
# QS act res 450765 [0.] 0
# QS act res 450846 [0.] 0
# QS act res 450927 [0.] 0
# QS act res 451008 [0.] 0
# QS act res 451089 [0.] 0
# QS act res 451170 [0.] 0
# QS act res 451251 [0.] 0
# QS act res 451332 [0.] 0
# QS act res 451413 [0.] 0
# QS act res 451494 [0.] 0
# QS act res 451575 [0.] 0
# QS act res 451656 [0.] 0
# QS act res 451737 [0.] 0
# QS act res 451818 [0.] 0
# QS act res 451899 [0.] 0
# QS act res 451980 [0.] 0
# QS act res 452061 [0.] 0
# QS act res 452142 [0.] 0
# QS act res 452223 [0.] 0
# QS act res 452304 [0.] 0
# QS act res 452385 [0.] 0
# QS act res 452466 [0.] 0
# QS act res 452547 [0.] 0
# QS act res 452628 [0.] 0
# QS act res 452709 [0.] 0
# QS act res 452790 [0.] 0
# QS act res 452871 [0.] 0
# QS act res 452952 [0.] 0
# QS act res 453033 [0.] 0
# QS act res 461052 [0.] 0
# QS act res 461133 [0.] 0
# QS act res 461214 [0.] 0
# QS act res 461295 [0.] 0
# QS act res 461376 [0.] 0
# QS act res 461457 [0.] 0
# QS act res 461538 [0.] 0
# QS act res 461619 [0.] 0
# QS act res 461700 [0.] 0
# QS act res 461781 [0.] 0
# QS act res 461862 [0.] 0
# QS act res 461943 [0.] 0
# QS act res 462024 [0.] 0
# QS act res 462105 [0.] 0
# QS act res 462186 [0.] 0
# QS act res 462267 [0.] 0
# QS act res 462348 [0.] 0
# QS act res 462429 [0.] 0
# QS act res 462510 [0.] 0
# QS act res 462591 [0.] 0
# QS act res 462672 [0.] 0
# QS act res 462753 [0.] 0
# QS act res 462834 [0.] 0
# QS act res 462915 [0.] 0
# QS act res 462996 [0.] 0
# QS act res 463077 [0.] 0
# QS act res 463158 [0.] 0
# QS act res 463239 [0.] 0
# QS act res 463320 [0.] 0
# QS act res 463401 [0.] 0
# QS act res 463482 [0.] 0
# QS act res 463563 [0.] 0
# QS act res 463644 [0.] 0
# QS act res 463725 [0.] 0
# QS act res 463806 [0.] 0
# QS act res 463887 [0.] 0
# QS act res 463968 [0.] 0
# QS act res 464049 [0.] 0
# QS act res 464130 [0.] 0
# QS act res 464211 [0.] 0
# QS act res 464292 [0.] 0
# QS act res 464373 [0.] 0
# QS act res 464454 [0.] 0
# QS act res 464535 [0.] 0
# QS act res 464616 [0.] 0
# QS act res 464697 [0.] 0
# QS act res 464778 [0.] 0
# QS act res 464859 [0.] 0
# QS act res 464940 [0.] 0
# QS act res 465021 [0.] 0
# QS act res 465102 [0.] 0
# QS act res 465183 [0.] 0
# QS act res 465264 [0.] 0
# QS act res 465345 [0.] 0
# QS act res 465426 [0.] 0
# QS act res 465507 [0.] 0
# QS act res 465588 [0.] 0
# QS act res 465669 [0.] 0
# QS act res 465750 [0.] 0
# QS act res 465831 [0.] 0
# QS act res 465912 [0.] 0
# QS act res 465993 [0.] 0
# QS act res 466074 [0.] 0
# QS act res 466155 [0.] 0
# QS act res 466236 [0.] 0
# QS act res 466317 [0.] 0
# QS act res 466398 [0.] 0
# QS act res 466479 [0.] 0
# QS act res 466560 [0.] 0
# QS act res 466641 [0.] 0
# QS act res 466722 [0.] 0
# QS act res 466803 [0.] 0
# QS act res 466884 [0.] 0
# QS act res 466965 [0.] 0
# QS act res 467046 [0.] 0
# QS act res 467127 [0.] 0
# QS act res 467208 [0.] 0
# QS act res 467289 [0.] 0
# QS act res 467370 [0.] 0
# QS act res 467451 [0.] 0
# QS act res 467532 [0.] 0
# QS act res 467613 [0.] 0
# QS act res 467694 [0.] 0
# QS act res 467775 [0.] 0
# QS act res 467856 [0.] 0
# QS act res 467937 [0.] 0
# QS act res 468018 [0.] 0
# QS act res 468099 [0.] 0
# QS act res 468180 [0.] 0
# QS act res 468261 [0.] 0
# QS act res 468342 [0.] 0
# QS act res 468423 [0.] 0
# QS act res 468504 [0.] 0
# QS act res 468585 [0.] 0
# QS act res 468666 [0.] 0
# QS act res 468747 [0.] 0
# QS act res 468828 [0.] 0
# QS act res 468909 [0.] 0
# QS act res 468990 [0.] 0
# QS act res 469071 [0.] 0
# QS act res 469152 [0.] 0
# QS act res 469233 [0.] 0
# QS act res 469314 [0.] 0
# QS act res 469395 [0.] 0
# QS act res 469476 [0.] 0
# QS act res 469557 [0.] 0
# QS act res 469638 [0.] 0
# QS act res 469719 [0.] 0
# QS act res 469800 [0.] 0
# QS act res 469881 [0.] 0
# QS act res 469962 [0.] 0
# QS act res 470043 [0.] 0
# QS act res 470124 [0.] 0
# QS act res 470205 [0.] 0
# QS act res 470286 [0.] 0
# QS act res 470367 [0.] 0
# QS act res 470448 [0.] 0
# QS act res 470529 [0.] 0
# QS act res 470610 [0.] 0
# QS act res 470691 [0.] 0
# QS act res 470772 [0.] 0
# QS act res 470853 [0.] 0
# QS act res 470934 [0.] 0
# QS act res 471015 [0.] 0
# QS act res 471096 [0.] 0
# QS act res 471177 [0.] 0
# QS act res 471258 [0.] 0
# QS act res 471339 [0.] 0
# QS act res 471420 [0.] 0
# QS act res 471501 [0.] 0
# QS act res 471582 [0.] 0
# QS act res 471663 [0.] 0
# QS act res 471744 [0.] 0
# QS act res 471825 [0.] 0
# QS act res 471906 [0.] 0
# QS act res 471987 [0.] 0
# QS act res 472068 [0.] 0
# QS act res 472149 [0.] 0
# QS act res 472230 [0.] 0
# QS act res 472311 [0.] 0
# QS act res 472392 [0.] 0
# QS act res 472473 [0.] 0
# QS act res 472554 [0.] 0
# QS act res 472635 [0.] 0
# QS act res 472716 [0.] 0
# QS act res 472797 [0.] 0
# QS act res 472878 [0.] 0
# QS act res 472959 [0.] 0
# QS act res 473040 [0.] 0
# QS act res 473121 [0.] 0
# QS act res 473202 [0.] 0
# QS act res 473283 [0.] 0
# QS act res 473364 [0.] 0
# QS act res 473445 [0.] 0
# QS act res 473526 [0.] 0
# QS act res 473607 [0.] 0
# QS act res 473688 [0.] 0
# QS act res 473769 [0.] 0
# QS act res 473850 [0.] 0
# QS act res 473931 [0.] 0
# QS act res 474012 [0.] 0
# QS act res 474093 [0.] 0
# QS act res 474174 [0.] 0
# QS act res 474255 [0.] 0
# QS act res 474336 [0.] 0
# QS act res 474417 [0.] 0
# QS act res 474498 [0.] 0
# QS act res 474579 [0.] 0
# QS act res 474660 [0.] 0
# QS act res 474741 [0.] 0
# QS act res 474822 [0.] 0
# QS act res 474903 [0.] 0
# QS act res 474984 [0.] 0
# QS act res 475065 [0.] 0
# QS act res 475146 [0.] 0
# QS act res 475227 [0.] 0
# QS act res 475308 [0.] 0
# QS act res 475389 [0.] 0
# QS act res 475470 [0.] 0
# QS act res 475551 [0.] 0
# QS act res 475632 [0.] 0
# QS act res 475713 [0.] 0
# QS act res 475794 [0.] 0
# QS act res 475875 [0.] 0
# QS act res 475956 [0.] 0
# QS act res 476037 [0.] 0
# QS act res 476118 [0.] 0
# QS act res 476199 [0.] 0
# QS act res 476280 [0.] 0
# QS act res 476361 [0.] 0
# QS act res 476442 [0.] 0
# QS act res 476523 [0.] 0
# QS act res 476604 [0.] 0
# QS act res 476685 [0.] 0
# QS act res 476766 [0.] 0
# QS act res 476847 [0.] 0
# QS act res 476928 [0.] 0
# QS act res 477009 [0.] 0
# QS act res 477090 [0.] 0
# QS act res 477171 [0.] 0
# QS act res 477252 [0.] 0
# QS act res 477333 [0.] 0
# QS act res 477414 [0.] 0
# QS act res 477495 [0.] 0
# QS act res 477576 [0.] 0
# QS act res 477657 [0.] 0
# QS act res 477738 [0.] 0
# QS act res 477819 [0.] 0
# QS act res 477900 [0.] 0
# QS act res 477981 [0.] 0
# QS act res 478062 [0.] 0
# QS act res 478143 [0.] 0
# QS act res 478224 [0.] 0
# QS act res 478305 [0.] 0
# QS act res 478386 [0.] 0
# QS act res 478467 [0.] 0
# QS act res 478548 [0.] 0
# QS act res 478629 [0.] 0
# QS act res 478710 [0.] 0
# QS act res 478791 [0.] 0
# QS act res 478872 [0.] 0
# QS act res 478953 [0.] 0
# QS act res 479034 [0.] 0
# QS act res 479115 [0.] 0
# QS act res 479196 [0.] 0
# QS act res 479277 [0.] 0
# QS act res 479358 [0.] 0
# QS act res 479439 [0.] 0
# QS act res 479520 [0.] 0
# QS act res 479601 [0.] 0
# QS act res 479682 [0.] 0
# QS act res 479763 [0.] 0
# QS act res 479844 [0.] 0
# QS act res 479925 [0.] 0
# QS act res 480006 [0.] 0
# QS act res 480087 [0.] 0
# QS act res 480168 [0.] 0
# QS act res 480249 [0.] 0
# QS act res 480330 [0.] 0
# QS act res 480411 [0.] 0
# QS act res 480492 [0.] 0
# QS act res 480573 [0.] 0
# QS act res 480654 [0.] 0
# QS act res 480735 [0.] 0
# QS act res 480816 [0.] 0
# QS act res 480897 [0.] 0
# QS act res 480978 [0.] 0
# QS act res 481059 [0.] 0
# QS act res 481140 [0.] 0
# QS act res 481221 [0.] 0
# QS act res 481302 [0.] 0
# QS act res 481383 [0.] 0
# QS act res 481464 [0.] 0
# QS act res 481545 [0.] 0
# QS act res 481626 [0.] 0
# QS act res 481707 [0.] 0
# QS act res 481788 [0.] 0
# QS act res 481869 [0.] 0
# QS act res 481950 [0.] 0
# QS act res 482031 [0.] 0
# QS act res 482112 [0.] 0
# QS act res 482193 [0.] 0
# QS act res 482274 [0.] 0
# QS act res 482355 [0.] 0
# QS act res 482436 [0.] 0
# QS act res 482517 [0.] 0
# QS act res 482598 [0.] 0
# QS act res 482679 [0.] 0
# QS act res 482760 [0.] 0
# QS act res 482841 [0.] 0
# QS act res 482922 [0.] 0
# QS act res 483003 [0.] 0
# QS act res 483084 [0.] 0
# QS act res 483165 [0.] 0
# QS act res 483246 [0.] 0
# QS act res 483327 [0.] 0
# QS act res 483408 [0.] 0
# QS act res 483489 [0.] 0
# QS act res 483570 [0.] 0
# QS act res 483651 [0.] 0
# QS act res 483732 [0.] 0
# QS act res 483813 [0.] 0
# QS act res 483894 [0.] 0
# QS act res 483975 [0.] 0
# QS act res 484056 [0.] 0
# QS act res 484137 [0.] 0
# QS act res 484218 [0.] 0
# QS act res 484299 [0.] 0
# QS act res 484380 [0.] 0
# QS act res 484461 [0.] 0
# QS act res 484542 [0.] 0
# QS act res 484623 [0.] 0
# QS act res 484704 [0.] 0
# QS act res 484785 [0.] 0
# QS act res 484866 [0.] 0
# QS act res 484947 [0.] 0
# QS act res 485028 [0.] 0
# QS act res 485109 [0.] 0
# QS act res 485190 [0.] 0
# QS act res 485271 [0.] 0
# QS act res 485352 [0.] 0
# QS act res 485433 [0.] 0
# QS act res 485514 [0.] 0
# QS act res 485595 [0.] 0
# QS act res 485676 [0.] 0
# QS act res 485757 [0.] 0
# QS act res 485838 [0.] 0
# QS act res 485919 [0.] 0
# QS act res 486000 [0.] 0
# QS act res 486081 [0.] 0
# QS act res 486162 [0.] 0
# QS act res 486243 [0.] 0
# QS act res 486324 [0.] 0
# QS act res 486405 [0.] 0
# QS act res 486486 [0.] 0
# QS act res 486567 [0.] 0
# QS act res 486648 [0.] 0
# QS act res 486729 [0.] 0
# QS act res 486810 [0.] 0
# QS act res 486891 [0.] 0
# QS act res 486972 [0.] 0
# QS act res 487053 [0.] 0
# QS act res 487134 [0.] 0
# QS act res 487215 [0.] 0
# QS act res 487296 [0.] 0
# QS act res 487377 [0.] 0
# QS act res 487458 [0.] 0
# QS act res 487539 [0.] 0
# QS act res 487620 [0.] 0
# QS act res 487701 [0.] 0
# QS act res 487782 [0.] 0
# QS act res 487863 [0.] 0
# QS act res 487944 [0.] 0
# QS act res 488025 [0.] 0
# QS act res 488106 [0.] 0
# QS act res 488187 [0.] 0
# QS act res 488268 [0.] 0
# QS act res 488349 [0.] 0
# QS act res 488430 [0.] 0
# QS act res 488511 [0.] 0
# QS act res 488592 [0.] 0
# QS act res 488673 [0.] 0
# QS act res 488754 [0.] 0
# QS act res 488835 [0.] 0
# QS act res 488916 [0.] 0
# QS act res 488997 [0.] 0
# QS act res 489078 [0.] 0
# QS act res 489159 [0.] 0
# QS act res 489240 [0.] 0
# QS act res 489321 [0.] 0
# QS act res 489402 [0.] 0
# QS act res 489483 [0.] 0
# QS act res 489564 [0.] 0
# QS act res 489645 [0.] 0
# QS act res 489726 [0.] 0
# QS act res 489807 [0.] 0
# QS act res 489888 [0.] 0
# QS act res 489969 [0.] 0
# QS act res 490050 [0.] 0
# QS act res 490131 [0.] 0
# QS act res 490212 [0.] 0
# QS act res 490293 [0.] 0
# QS act res 490374 [0.] 0
# QS act res 490455 [0.] 0
# QS act res 490536 [0.] 0
# QS act res 490617 [0.] 0
# QS act res 490698 [0.] 0
# QS act res 490779 [0.] 0
# QS act res 490860 [0.] 0
# QS act res 490941 [0.] 0
# QS act res 491022 [0.] 0
# QS act res 491103 [0.] 0
# QS act res 491184 [0.] 0
# QS act res 491265 [0.] 0
# QS act res 491346 [0.] 0
# QS act res 491427 [0.] 0
# QS act res 491508 [0.] 0
# QS act res 491589 [0.] 0
# QS act res 491670 [0.] 0
# QS act res 491751 [0.] 0
# QS act res 491832 [0.] 0
# QS act res 491913 [0.] 0
# QS act res 491994 [0.] 0
# QS act res 492075 [0.] 0
# QS act res 492156 [0.] 0
# QS act res 492237 [0.] 0
# QS act res 492318 [0.] 0
# QS act res 492399 [0.] 0
# QS act res 492480 [0.] 0
# QS act res 492561 [0.] 0
# QS act res 492642 [0.] 0
# QS act res 492723 [0.] 0
# QS act res 492804 [0.] 0
# QS act res 492885 [0.] 0
# QS act res 492966 [0.] 0
# QS act res 493047 [0.] 0
# QS act res 493128 [0.] 0
# QS act res 493209 [0.] 0
# QS act res 493290 [0.] 0
# QS act res 493371 [0.] 0
# QS act res 493452 [0.] 0
# QS act res 493533 [0.] 0
# QS act res 493614 [0.] 0
# QS act res 493695 [0.] 0
# QS act res 493776 [0.] 0
# QS act res 493857 [0.] 0
# QS act res 493938 [0.] 0
# QS act res 494019 [0.] 0
# QS act res 494100 [0.] 0
# QS act res 494181 [0.] 0
# QS act res 494262 [0.] 0
# QS act res 494343 [0.] 0
# QS act res 494424 [0.] 0
# QS act res 494505 [0.] 0
# QS act res 494586 [0.] 0
# QS act res 494667 [0.] 0
# QS act res 494748 [0.] 0
# QS act res 494829 [0.] 0
# QS act res 494910 [0.] 0
# QS act res 494991 [0.] 0
# QS act res 495072 [0.] 0
# QS act res 495153 [0.] 0
# QS act res 495234 [0.] 0
# QS act res 495315 [0.] 0
# QS act res 495396 [0.] 0
# QS act res 495477 [0.] 0
# QS act res 495558 [0.] 0
# QS act res 495639 [0.] 0
# QS act res 495720 [0.] 0
# QS act res 495801 [0.] 0
# QS act res 495882 [0.] 0
# QS act res 495963 [0.] 0
# QS act res 496044 [0.] 0
# QS act res 496125 [0.] 0
# QS act res 496206 [0.] 0
# QS act res 496287 [0.] 0
# QS act res 496368 [0.] 0
# QS act res 496449 [0.] 0
# QS act res 496530 [0.] 0
# QS act res 496611 [0.] 0
# QS act res 496692 [0.] 0
# QS act res 496773 [0.] 0
# QS act res 496854 [0.] 0
# QS act res 496935 [0.] 0
# QS act res 497016 [0.] 0
# QS act res 497097 [0.] 0
# QS act res 497178 [0.] 0
# QS act res 497259 [0.] 0
# QS act res 497340 [0.] 0
# QS act res 497421 [0.] 0
# QS act res 497502 [0.] 0
# QS act res 497583 [0.] 0
# QS act res 497664 [0.] 0
# QS act res 497745 [0.] 0
# QS act res 497826 [0.] 0
# QS act res 497907 [0.] 0
# QS act res 497988 [0.] 0
# QS act res 498069 [0.] 0
# QS act res 498150 [0.] 0
# QS act res 498231 [0.] 0
# QS act res 498312 [0.] 0
# QS act res 498393 [0.] 0
# QS act res 498474 [0.] 0
# QS act res 498555 [0.] 0
# QS act res 498636 [0.] 0
# QS act res 498717 [0.] 0
# QS act res 498798 [0.] 0
# QS act res 498879 [0.] 0
# QS act res 498960 [0.] 0
# QS act res 499041 [0.] 0
# QS act res 499122 [0.] 0
# QS act res 499203 [0.] 0
# QS act res 499284 [0.] 0
# QS act res 499365 [0.] 0
# QS act res 499446 [0.] 0
# QS act res 499527 [0.] 0
# QS act res 499608 [0.] 0
# QS act res 499689 [0.] 0
# QS act res 499770 [0.] 0
# QS act res 499851 [0.] 0
# QS act res 499932 [0.] 0

# %%
t_fin=1000000
plt.semilogy(frac[:t_fin,0], frac[:t_fin,1])
plt.semilogy(frac[:t_fin,0], frac[:t_fin,2])
